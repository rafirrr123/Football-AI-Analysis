# %%
from roboflow import Roboflow
rf = Roboflow(api_key="7pclQE8G2yWNN4ihcgrX")
project = rf.workspace("school-research").project("football-and-player-detection-ef0dh")
version = project.version(10)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Football-And-Player-Detection--10 in yolov11:: 100%|██████████| 2268/2268 [00:03<00:00, 754.94it/s]

# %%
from ultralytics import YOLO

model = YOLO("yolo11s.pt")

model.train(
    data="Football-And-Player-Detection--10/data.yaml",
    epochs=100,
    imgsz=640,
    batch=8,
    device=0
)
# Out:
# Ultralytics 8.4.131  Python-3.10.11 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# ...
